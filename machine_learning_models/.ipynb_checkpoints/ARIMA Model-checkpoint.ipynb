# %% [markdown]
# # ARIMA Model for Weekly Total Energy Demand Forecasting
#
# 1. **Imports:**
#     - pandas: For data manipulation and analysis.
#     - matplotlib.pyplot: For data visualization.
#     - pmdarima: For the auto ARIMA model to automatically select the best ARIMA parameters.
#     - sklearn.metrics: For calculating the mean squared error (RMSE) to evaluate model performance.
#     - math.sqrt: For computing the square root of the mean squared error to obtain the RMSE.
#
# 2. **Load Data:**
#     - Load the energy consumption dataset from a CSV file using pd.read_csv(), with dates parsed and set as the DataFrame index.
#
#
# 3. **Data Exploration and Preprocessing**
#     - View the raw dataset info() and head()
#     - Create 'Total Energy Demand' Column: Sum the relevant columns (excluding 'use [kW]' and 'gen [kW]' due to all zeros) to calculate the total energy demand.
#     - Visualize the dataset
#
# 4. **Weekly Resampling:**
#     - Aggregate the total energy demand on a weekly basis to form the time series for forecasting.
#
# 5. **Ensure Sufficient Data:**
#     - Check if there are enough data points (e.g., at least 30 weeks) to proceed with modeling and forecasting.
#
# 6. **Train-Test Split:**
#     - Split the weekly aggregated data into training and testing sets, reserving the last 4 weeks for testing the model's forecasting ability.
#
# 7. **Model Selection and Training:**
#     - Use auto_arima from pmdarima to automatically find the best fitting ARIMA model parameters, checking for stationarity, seasonality, and model order.
#
# 8. **Model Summary:**
#     - Print the summary of the best ARIMA model selected by auto_arima.
#
# 9. **Forecasting:**
#     - Forecast the total energy demand for the next 4 weeks using the trained ARIMA model.
#
# 10. **Evaluation:**
#     - Compute the Root Mean Squared Error (RMSE) between the actual and forecasted values.
#
# 11. **Visualization:**
#     - Plot the historical data (training set), actual future values (test set), and the model's forecasts.
#
#
# **Conclusion:**
# The auto model works well in choosing the best ARIMA model for making our predictions, however due to a limited dataset, being only 53 instances, the RMSE scores poorly at 1474.30. This result is viewable in the new months predicted data, which is off from the actual data that shows a sharp drop in January's total energy useage.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
# Load the data
file_path = 'HomeA-meter4_2016.csv'
cleaned_data_file2016 = '../data_files/HomeA-meter4_2016.csv'
cleaned_data_file2015 = '../data_files/HomeA-meter4_2015.csv'
cleaned_data_file2014 = '../data_files/HomeA-meter4_2014.csv'
df2016 = pd.read_csv(cleaned_data_file2016, parse_dates=['Date & Time'], index_col='Date & Time')
df2015 = pd.read_csv(cleaned_data_file2015, parse_dates=['Date & Time'], index_col='Date & Time')
df2014 = pd.read_csv(cleaned_data_file2014, parse_dates=['Date & Time'], index_col='Date & Time')

df = pd.concat([df2014, df2015, df2016])
# Drop 'use [kW]' and 'gen [kW]' columns
df.drop(columns=['use [kW]', 'gen [kW]'], inplace=True)
df.dropna(inplace=True)

# Save the concatenated DataFrame to a new CSV file
output_file_path = '../data_files/HomeA-meter4_2014_to_2016.csv'
df.to_csv(output_file_path)
print(f"Concatenated DataFrame saved to: {output_file_path}")


# Data Exploration
df.info()
print(df.head())

# Create 'Total Energy Demand' column

df['Total Energy Demand'] = df.sum(axis=1)
# Assuming df is your DataFrame after loading and preprocessing
df_weekly = df['Total Energy Demand'].resample('W').sum()

df_weekly = df_weekly[df_weekly != 0.0]
print(df_weekly.head())

# Plot the total energy demand
df_weekly.plot(figsize=(10, 6))
plt.ylabel('Energy Demand (kW)')
plt.title('Total Energy Demand Over Time')
plt.show()
# Out:
# Concatenated DataFrame saved to: ../data_files/HomeA-meter4_2014_to_2016.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 572823 entries, 2014-01-01 00:00:00 to 2016-12-31 23:59:00
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   KitchenDenLights [kW]             572823 non-null  float64
#  1   MasterBedBathLights [kW]          572823 non-null  float64
#  2   MasterOutlets [kW]                572823 non-null  float64
#  3   DenOutdoorLights [kW]             572823 non-null  float64
#  4   DenOutlets [kW]                   572823 non-null  float64
#  5   RearBasementLights [kW]           572823 non-null  float64
#  6   KitchenOutletsEast [kW]           572823 non-null  float64
#  7   KitchenOutletsSouth [kW]          572823 non-null  float64
#  8   DishwasherDisposalSinkLight [kW]  572823 non-null  float64
#  9   Refrigerator [kW]                 572823 non-null  float64
#  10  Microwave [kW]                    572823 non-null  float64
#  11  OfficeLights [kW]                 572823 non-null  float64
# dtypes: float64(12)
# memory usage: 56.8 MB
#                      KitchenDenLights [kW]  MasterBedBathLights [kW]  \
# Date & Time
# 2014-01-01 00:00:00                    0.0                       0.0
# 2014-01-01 00:15:00                    0.0                       0.0
# 2014-01-01 00:30:00                    0.0                       0.0
# 2014-01-01 00:45:00                    0.0                       0.0
# 2014-01-01 01:00:00                    0.0                       0.0
#
#                      MasterOutlets [kW]  DenOutdoorLights [kW]  \
# Date & Time
# 2014-01-01 00:00:00                 0.0                    0.0
# 2014-01-01 00:15:00                 0.0                    0.0
# 2014-01-01 00:30:00                 0.0                    0.0
# 2014-01-01 00:45:00                 0.0                    0.0
# 2014-01-01 01:00:00                 0.0                    0.0
#
#                      DenOutlets [kW]  RearBasementLights [kW]  \
# Date & Time
# 2014-01-01 00:00:00              0.0                      0.0
# 2014-01-01 00:15:00              0.0                      0.0
# 2014-01-01 00:30:00              0.0                      0.0
# 2014-01-01 00:45:00              0.0                      0.0
# 2014-01-01 01:00:00              0.0                      0.0
#
#                      KitchenOutletsEast [kW]  KitchenOutletsSouth [kW]  \
# Date & Time
# 2014-01-01 00:00:00                      0.0                       0.0
# 2014-01-01 00:15:00                      0.0                       0.0
# 2014-01-01 00:30:00                      0.0                       0.0
# 2014-01-01 00:45:00                      0.0                       0.0
# 2014-01-01 01:00:00                      0.0                       0.0
#
#                      DishwasherDisposalSinkLight [kW]  Refrigerator [kW]  \
# Date & Time
# 2014-01-01 00:00:00                               0.0                0.0
# 2014-01-01 00:15:00                               0.0                0.0
# 2014-01-01 00:30:00                               0.0                0.0
# 2014-01-01 00:45:00                               0.0                0.0
# 2014-01-01 01:00:00                               0.0                0.0
#
#                      Microwave [kW]  OfficeLights [kW]
# Date & Time
# 2014-01-01 00:00:00             0.0                0.0
# 2014-01-01 00:15:00             0.0                0.0
# 2014-01-01 00:30:00             0.0                0.0
# 2014-01-01 00:45:00             0.0                0.0
# 2014-01-01 01:00:00             0.0                0.0
# Date & Time
# 2015-06-07    3934.179522
# 2015-06-14     173.599466
# 2015-06-21     171.814516
# 2015-06-28     151.666813
# 2015-07-05     198.901973
# Freq: W-SUN, Name: Total Energy Demand, dtype: float64

# %%
df_weekly.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 83 entries, 2015-06-07 to 2017-01-01
# Freq: W-SUN
# Series name: Total Energy Demand
# Non-Null Count  Dtype
# --------------  -----
# 83 non-null     float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
# Create an ARIMA model based on the best fit using auto_arima

# Ensure there's enough data to split into train and test
if len(df_weekly) < 30:  # threshold to ensure enough data points
    print("Not enough data points for meaningful modeling.")
else:
    # Splitting the data into train and test sets
    n_test = 4  # number of data points to withhold for testing
    train, test = df_weekly[:-n_test], df_weekly[-n_test:]

    # Using auto_arima to find the best ARIMA parameters
    auto_model = auto_arima(train, seasonal=True, stepwise=True, suppress_warnings=True,
                            error_action="ignore", max_order=None, trace=True)

    print(auto_model.summary())

    # Fit ARIMA model
    model_fit = auto_model.fit(train)

    model_fit.plot_diagnostics(figsize=(15, 12))
    plt.show()
    
    # Forecast
    forecast = model_fit.predict(n_periods=n_test)
    forecast_series = pd.Series(forecast, index=test.index)  # Creating a Series for the forecast to align with the test data index
    
    # Evaluation
    rmse = sqrt(mean_squared_error(test, forecast))
    print(f'Test RMSE: {rmse}')

    # Visualization
    plt.figure(figsize=(10, 6))
    plt.plot(train.index, train, label='Train')
    plt.plot(test.index, test, color='orange', label='Test')
    plt.plot(test.index, forecast, color='green', label='Forecast')
    plt.title('Weekly Total Energy Demand Forecast - 4 Weeks ahead')
    plt.xlabel('Date')
    plt.ylabel('Total Energy Demand')
    plt.legend()
    plt.show()
    
    # Saving datasets for Tableau
    train.to_csv('train_data.csv')
    test.to_csv('test_data.csv')
    forecast_series.to_csv('forecast_data.csv')
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1242.166, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1239.544, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1237.210, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1236.392, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1237.573, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1238.142, Time=0.28 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1238.011, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1234.640, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1236.366, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1236.397, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1235.318, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.804 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   79
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -615.320
# Date:                Sun, 25 Feb 2024   AIC                           1234.640
# Time:                        14:23:53   BIC                           1239.354
# Sample:                    06-07-2015   HQIC                          1236.527
#                          - 12-04-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3017      0.077     -3.910      0.000      -0.453      -0.150
# sigma2      4.343e+05   3.35e+04     12.970      0.000    3.69e+05       5e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.22   Jarque-Bera (JB):               438.10
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                            -0.46
# Prob(H) (two-sided):                  1.00   Kurtosis:                        14.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Test RMSE: 1438.013298618209

# %%
# Combine the train, test, and forecast series into a single DataFrame
combined_df = pd.concat([train.rename('Actual'), test.rename('Test Actual'), forecast_series.rename('Forecast')], axis=1)

# Fill any missing values in the Forecast column with NaN
combined_df['Forecast'] = combined_df['Forecast'].reindex(combined_df.index)
combined_df.index = pd.to_datetime(combined_df.index)
combined_df.index = combined_df.index.map(lambda dt: dt.replace(hour=0, minute=0, second=0))
#combined_df.index = combined_df.index.strftime('%Y-%m-%d %H:%M:%S')

# Save the combined DataFrame to a CSV file
combined_output_file_path = '../data_files/combined_energy_data.csv'
combined_df.to_csv(combined_output_file_path)
print(f"Combined DataFrame with actual and forecasted values saved to: {combined_output_file_path}")
# Out:
# Combined DataFrame with actual and forecasted values saved to: ../data_files/combined_energy_data.csv
